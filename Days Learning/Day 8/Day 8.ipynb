# %%
# %sql
-- Create structure
USE CATALOG ecommerce;
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

-- Register tables
CREATE TABLE IF NOT EXISTS bronze.events USING DELTA;
CREATE TABLE IF NOT EXISTS silver.events USING DELTA;
CREATE TABLE IF NOT EXISTS gold.products USING DELTA;

-- Permissions
--GRANT SELECT ON TABLE gold.products TO `ref`;
--GRANT ALL PRIVILEGES ON SCHEMA silver TO `engineers@company.com`;
